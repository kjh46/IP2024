# %% [markdown]
# #Accessing and Modifying pixel values

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('cat.jpg')

# %%
plt_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(plt_img, interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
img.shape
# Out:
# (780, 1170, 3)

# %%
img[100,100]
# Out:
# array([ 78,   0, 255], dtype=uint8)

# %%
img[100,100] = [0,0,0]

# %%
img[100,100]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
img[:10, :10]
# Out:
# array([[[184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [183, 223, 252]],
#
#        [[184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [186, 226, 255],
#         [184, 224, 253]],
#
#        [[184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [187, 227, 255],
#         [185, 225, 254]],
#
#        [[184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [186, 226, 255],
#         [185, 225, 254]],
#
#        [[184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [186, 226, 255],
#         [185, 225, 254]],
#
#        [[184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [186, 226, 255],
#         [184, 224, 253]],
#
#        [[184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [186, 226, 255],
#         [185, 225, 254]],
#
#        [[184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [185, 225, 254],
#         [188, 228, 255],
#         [186, 226, 255]],
#
#        [[184, 223, 255],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [186, 226, 254],
#         [186, 226, 254],
#         [187, 227, 255],
#         [187, 228, 253],
#         [188, 229, 254],
#         [186, 226, 254]],
#
#        [[184, 224, 253],
#         [184, 224, 253],
#         [185, 225, 254],
#         [185, 225, 254],
#         [186, 226, 254],
#         [186, 226, 254],
#         [187, 228, 253],
#         [187, 228, 253],
#         [188, 229, 254],
#         [187, 228, 253]]], dtype=uint8)

# %%
img[:100, :100,0] = [0]

# %%
img[180:300,400:750, 0] = 255

# %%
plt.imshow(img)
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
px = img[100,100]

# %%
print (px)
# Out:
# [0 0 0]

# %%
blue = img[100,100,0]

# %%
print (blue)
# Out:
# 0

# %%
img[100,100] = [255,255,255]

# %%
print (img[100,100])
# Out:
# [255 255 255]

# %%
img.item(10,10,2)
# Out:
# 254

# %%
img.itemset((10,10,2),100)
img.item(10,10,2)
# Out:
# 100

# %%
print (img.shape)
# Out:
# (780, 1170, 3)

# %%
print (img.size)
# Out:
# 2737800

# %%
print(img.dtype)
# Out:
# uint8

# %%
ball = img[280:340, 330:390]
img[273:333, 100:160] = ball

# %%
b,g,r = cv2.split(img)
img = cv2.merge((b,g,r))

# %%
img[:,:,2] = 0

# %%
plt.imshow(img)
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))
